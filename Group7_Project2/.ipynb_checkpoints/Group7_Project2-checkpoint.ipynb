# %% [markdown]
# ### Members' Full name:
#
# - Nguyen Mai Dinh, Le - 300312139
# - Ruiz, Ricardo - 300387021
# - Jimmy, Suwarly - 300361475
# - Hugh, Tran - 300394597

# %% [markdown]
# # Part A. Planning

# %% [markdown]
# # Part B. Basic Model

# %% [markdown]
# ### 1. Import Library + Data Loading (Demi)

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("faq.csv")
df2 = pd.read_csv("faq1.csv")
df3 = pd.read_csv("faq2.csv")
df4 = pd.read_csv("faq3.csv")
df5 = pd.read_csv("faq4.csv")
df6 = pd.read_csv("faq5.csv")
df7 = pd.read_csv("faq6.csv")
df8 = pd.read_csv("faq7.csv")

df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8], ignore_index=True)
df
# Out:
#                                              question  \
# 0                   How many programs can I apply to?
# 1                           What is the fee to apply?
# 2                     What is preferential admission?
# 3   How long is the wait-list for Douglas College ...
# 4   I got a letter saying I'm in the program. Why ...
# ..                                                ...
# 72  If a student has to stay home (flu symptoms, f...
# 73  If I am sick, are there alternatives to attend...
# 74  Will there be more options for online learning...
# 75  Will I be able to access online classes / reco...
# 76  Can an ill student ask a classmate to audio/vi...
#
#                                                answer
# 0   You can indicate one program choice per applic...
# 1   $37.40 for Canadian/Permanent Residents. $100 ...
# 2   Preferential admission is a selective admissio...
# 3   There is no wait-list for open enrolment or li...
# 4   The first letter you received was an acknowled...
# ..                                                ...
# 72  It is expected that we may have higher than no...
# 73  Decision regarding attendance is the discretio...
# 74  While Douglas College is returning to primaril...
# 75  Not necessarily. Students should not have the ...
# 76  No, recording a class is not permitted without...
#
# [77 rows x 2 columns]

# %% [markdown]
# ### 2. Search Engine Building (Ricardo)

# %% [markdown]
# ### 3. Testing + Evaluation

# %% [markdown]
# #### 3.1. Precision@K Function + Testing + Evaluation function (Demi)

# %%
def run_queries(es, index_name, queries, top_k=5):
    results = {}
    
    for q in queries:
        response = es.search(
            index=index_name,
            body={
                "query": {
                    "multi_match": {
                        "query": q,
                        "fields": ["question^2", "answer"]
                    }
                },
                "size": top_k
            }
        )
        
        docs = []
        for hit in response["hits"]["hits"]:
            docs.append(hit["_source"])
        
        results[q] = docs
    
    return results

def precision_at_k(relevance_list, k=1):
    return sum(relevance_list[:k]) / k

def evaluate_precision_at_1(relevance_judgments):
    scores = []
    
    for rels in relevance_judgments.values():
        p1 = precision_at_k(rels, k=1)
        scores.append(p1)
    
    avg_p1 = sum(scores) / len(scores)
    
    return scores, avg_p1

def evaluate_precision_at_k(relevance_judgments, k=5):
    scores = []
    
    for rels in relevance_judgments.values():
        pk = precision_at_k(rels, k=k)
        scores.append(pk)
    
    avg_pk = sum(scores) / len(scores)
    
    return scores, avg_pk

# %% [markdown]
# #### 3.2. 20 questions + Evaluation (All)

# %% [markdown]
# **Demi**
#
# 5 questions
#
# Testing using the pre-built testing function
#
# Evaluation

# %% [markdown]
# **Ricardo**
#
# 5 questions
#
# Testing using the pre-built testing function
#
# Evaluation

# %% [markdown]
# **Jimmy**
#
# 5 questions
#
# Testing using the pre-built testing function
#
# Evaluation

# %% [markdown]
# **Hugh**
#
# 5 questions:
# - How can I submit my application?
# - What do I need to pay for tuition?
# - Where can I get advising help?
# - How do I talk to a student advisor?
# - What happens if I fail a course?
#
# Testing using the pre-built testing function
#
# Evaluation

# %% [markdown]
# # Part C. ElasticSearch with mbedding

# %% [markdown]
# ### 1. Discussion (Demi)

# %% [markdown]
# ### 2. Building Embedding (Hugh)

# %%
# pip install elasticsearch
# %pip install -U spacy
# !python -m spacy download en_core_web_lg

import re
import spacy
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from elasticsearch import Elasticsearch
# warnings.filterwarnings("ignore")

es = Elasticsearch(
    "https://localhost:9200",
    basic_auth=("elastic", "3y-I0U=GUbfXRiTe+*Rn"),
    verify_certs=False
)
print(es.info())
# Out:
# {'name': 'HTTK', 'cluster_name': 'elasticsearch', 'cluster_uuid': 'MlUnGcu4RrWRF8cRp--4lg', 'version': {'number': '9.3.1', 'build_flavor': 'default', 'build_type': 'zip', 'build_hash': '0dd66e52ba3aa076cf498264e46339dbb71f0269', 'build_date': '2026-02-23T23:37:38.684779921Z', 'build_snapshot': False, 'lucene_version': '10.3.2', 'minimum_wire_compatibility_version': '8.19.0', 'minimum_index_compatibility_version': '8.0.0'}, 'tagline': 'You Know, for Search'}
# C:\Users\qhung\anaconda3\Lib\site-packages\elasticsearch\_sync\client\__init__.py:313: SecurityWarning: Connecting to 'https://localhost:9200' using TLS with verify_certs=False is insecure
#   _transport = transport_class(
# C:\Users\qhung\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
nlp = spacy.load("en_core_web_lg")

# %%
def clean_text(text):
    text = str(text).lower().strip()
    text = re.sub(r"\s+", " ", text)
    return text

df["question_clean"] = df["question"].apply(clean_text)
df["answer_clean"] = df["answer"].apply(clean_text)
# df.info()

# %%
def get_embedding(text, nlp_model):
    return nlp_model(text).vector

df["question_vector"] = df["question_clean"].apply(lambda x: get_embedding(x, nlp))
# df["question_vector"]

# %%
faq_matrix = np.vstack(df["question_vector"].values)
faq_matrix.shape
# Out:
# (77, 300)

# %%
def semantic_search(query, df, faq_matrix, nlp_model, top_k=5):
    query_clean = clean_text(query)
    query_vector = nlp_model(query_clean).vector.reshape(1, -1)

    similarities = cosine_similarity(query_vector, faq_matrix)[0]
    top_indices = np.argsort(similarities)[::-1][:top_k]

    results = df.iloc[top_indices].copy()
    results["similarity_score"] = similarities[top_indices]

    return results[["question", "answer", "similarity_score"]]

# %%
test_query = "How can I apply to Douglas?"
semantic_search(test_query, df, faq_matrix, nlp, top_k=5)
# Out:
#                                              question  \
# 0                   How many programs can I apply to?
# 6   What if I don't get in this year? Do I have to...
# 49  I am almost done my program. How do I apply to...
# 12  I am out of the country, when should I come to...
# 61              How quickly can I get an appointment?
#
#                                                answer  similarity_score
# 0   You can indicate one program choice per applic...          0.929358
# 6   If all admission requirements have been met fo...          0.904084
# 49  You should apply to graduate after you have en...          0.901134
# 12  Classes that are scheduled as “in-person” or “...          0.897031
# 61  Counselling appointments are typically booked ...          0.894558

# %%
def run_semantic_queries(df, faq_matrix, queries, nlp_model, top_k=5):
    results = {}

    for q in queries:
        result_df = semantic_search(q, df, faq_matrix, nlp_model, top_k=top_k)
        results[q] = result_df

    return results

# %% [markdown]
# ### 2. Testing + Evaluation (All)

# %%
hugh_test_questions = [
    "How can I submit my application?",
    "What do I need to pay for tuition?",
    "Where can I get advising help?",
    "How do I talk to a student advisor?",
    "What happens if I fail a course?"
]

# %%
semantic_results = run_semantic_queries(df, faq_matrix, hugh_test_questions, nlp, top_k=5)

for q, res in semantic_results.items():
    print("=" * 100)
    print("QUESTION:", q)
    print(res)
    print()
# Out:
# ====================================================================================================
# QUESTION: How can I submit my application?
#                                              question  \
# 4   I got a letter saying I'm in the program. Why ...
# 49  I am almost done my program. How do I apply to...
# 61              How quickly can I get an appointment?
# 0                   How many programs can I apply to?
# 62  Do I need to prepare anything for my appointment?
#
#                                                answer  similarity_score
# 4   The first letter you received was an acknowled...          0.932356
# 49  You should apply to graduate after you have en...          0.920658
# 61  Counselling appointments are typically booked ...          0.913821
# 0   You can indicate one program choice per applic...          0.913310
# 62  No, you do not need to prepare anything. Howev...          0.909747
#
# ====================================================================================================
# QUESTION: What do I need to pay for tuition?
#                                              question  \
# 62  Do I need to prepare anything for my appointment?
# 6   What if I don't get in this year? Do I have to...
# 37  If I have not made any payments towards my acc...
# 10  Do I need a study permit to take classes if th...
# 46  What if I don’t know which program or career t...
#
#                                                answer  similarity_score
# 62  No, you do not need to prepare anything. Howev...          0.936224
# 6   If all admission requirements have been met fo...          0.932967
# 37  Regardless of whether payment is made or not, ...          0.931750
# 10  Yes. You are required to have a valid study pe...          0.927655
# 46  See a career counsellor for help with planning...          0.920637
#
# ====================================================================================================
# QUESTION: Where can I get advising help?
#                                              question  \
# 61              How quickly can I get an appointment?
# 46  What if I don’t know which program or career t...
# 0                   How many programs can I apply to?
# 10  Do I need a study permit to take classes if th...
# 62  Do I need to prepare anything for my appointment?
#
#                                                answer  similarity_score
# 61  Counselling appointments are typically booked ...          0.934587
# 46  See a career counsellor for help with planning...          0.926929
# 0   You can indicate one program choice per applic...          0.925846
# 10  Yes. You are required to have a valid study pe...          0.919593
# 62  No, you do not need to prepare anything. Howev...          0.916944
#
# ====================================================================================================
# QUESTION: How do I talk to a student advisor?
#                                              question  \
# 51  I'm interested in transferring to a university...
# 49  I am almost done my program. How do I apply to...
# 7               What if I'm an International student?
# 46  What if I don’t know which program or career t...
# 66  What can I talk about in my appointment? Can I...
#
#                                                answer  similarity_score
# 51  Please review our University Transfer page for...          0.928341
# 49  You should apply to graduate after you have en...          0.926645
# 7   For detailed and up-to-date information on Int...          0.925760
# 46  See a career counsellor for help with planning...          0.923109
# 66  You are welcome to bring up any topic of conce...          0.917173
#
# ====================================================================================================
# QUESTION: What happens if I fail a course?
#                                              question  \
# 6   What if I don't get in this year? Do I have to...
# 46  What if I don’t know which program or career t...
# 64  What if the counsellor I meet with is not a go...
# 4   I got a letter saying I'm in the program. Why ...
# 56            What can I expect in the first meeting?
#
#                                                answer  similarity_score
# 6   If all admission requirements have been met fo...          0.936743
# 46  See a career counsellor for help with planning...          0.934253
# 64  We encourage you to keep meeting with the same...          0.921258
# 4   The first letter you received was an acknowled...          0.920782
# 56  You’ll begin your meeting with a review of our...          0.915177

# %% [markdown]
# # Part D. FAQBot using Gemini

# %% [markdown]
# ### 1. RAG Building (Jimmy)

# %% [markdown]
# ### 2. Testing + Evaluation (All)

# %% [markdown]
# # Part E. Final Conclusion + Compare Results (Demi)
